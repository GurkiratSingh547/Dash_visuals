# %%
import dash
from dash import dcc, html, Input, Output
import yfinance as yf
import plotly.graph_objs as go

app = dash.Dash(__name__)

app.layout = html.Div([
    html.H1('trends of stock price'),
    dcc.Input(id='stock-symbol', type='text', placeholder='Enter stock symbol'),
    dcc.Graph(id='stock-graph')
])

@app.callback(
    Output('stock-graph', 'figure'),
    [Input('stock-symbol', 'value')]
)
def update_graph(stock_symbol):
    if not stock_symbol:
        return go.Figure()

    # Fetch data from Yahoo Finance
    data = yf.download(stock_symbol, period='5y')

    # Create a candlestick graph
    figure = go.Figure(data=[go.Candlestick(
        x=data.index,
        open=data['Open'],
        high=data['High'],
        low=data['Low'],
        close=data['Close']
    )])

    figure.update_layout(
        title=f'{stock_symbol} Stock Price',
        xaxis_title='Date',
        yaxis_title='Price',
        xaxis_rangeslider_visible=False
    )

    return figure

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# [*********************100%***********************]  1 of 1 completed

# %%
from IPython.display import display, HTML
display(HTML('<a href="http://127.0.0.1:8050/" target="_blank">Open Dash App</a>'))
# Out:
# <a href="http://127.0.0.1:8050/" target="_blank">Open Dash App</a>
# [*********************100%***********************]  1 of 1 completed
#
#
#
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\yfinance\utils.py:107, in log_indent_decorator.<locals>.wrapper(
#     *args=('AA',),
#     **kwargs={'period': '5y'}
# )
#     104 logger.debug(f'Entering {func.__name__}()')
#     106 with IndentationContext():
# --> 107     result = func(*args, **kwargs)
#         func = <function download at 0x00000260E8D18040>
#         args = ('AA',)
#         kwargs = {'period': '5y'}
#     109 logger.debug(f'Exiting {func.__name__}()')
#     110 return result
#
# File ~\anaconda3\lib\site-packages\yfinance\multi.py:210, in download(
#     tickers=['AA'],
#     start=None,
#     end=None,
#     actions=False,
#     threads=1,
#     ignore_tz=True,
# ...
